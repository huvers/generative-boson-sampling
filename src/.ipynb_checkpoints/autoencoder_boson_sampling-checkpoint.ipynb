# %%
import os
import numpy as np
import pickle
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, save_img, img_to_array
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt

from models.AED import Autoencoder

# %%
# run params
SECTION = 'vae'
RUN_ID = '0001'
DATA_NAME = 'boson/'
RUN_FOLDER = '../run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])
print(RUN_FOLDER)

if not os.path.exists(RUN_FOLDER):
    os.makedirs(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

MODE =  'build' #'load' #
# Out:
# ../run/vae/0001_boson/

# %%
data_file = '../data/data.sav'

with open(data_file, "rb") as f:
    X, Y = pickle.load(f)
    
X = np.asarray(X)
Y = np.asarray(Y)

split = round(len(X)*.85)

x_train = X[:split]
y_train = Y[:split]

x_test  = X[split:]
y_test  = Y[split:]

# %%
AE = Autoencoder(
    input_dim = (x_train.shape[1],)
    , encoder_dense_layers = [64,64,32,128]
    , decoder_dense_layers = [64,64,32, 35]
    , z_dim = 12
    , use_dropout = True
)

if MODE == 'build':
    AE.save(RUN_FOLDER)
else:
    AE.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
AE.encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 25)]              0
# _________________________________________________________________
# encoder_dense_0 (Dense)      (None, 64)                1664
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# encoder_dense_1 (Dense)      (None, 64)                4160
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# encoder_dense_2 (Dense)      (None, 32)                2080
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# encoder_dense_3 (Dense)      (None, 128)               4224
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# encoder_output (Dense)       (None, 12)                1548
# =================================================================
# Total params: 13,676
# Trainable params: 13,676
# Non-trainable params: 0
# _________________________________________________________________

# %%
AE.decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 12)]              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1664
# _________________________________________________________________
# reshape (Reshape)            (None, 128)               0
# _________________________________________________________________
# decoder_dense_t_0 (Dense)    (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# decoder_dense_t_1 (Dense)    (None, 64)                4160
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# decoder_dense_t_2 (Dense)    (None, 32)                2080
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# decoder_dense_t_3 (Dense)    (None, 35)                1155
# _________________________________________________________________
# activation (Activation)      (None, 35)                0
# =================================================================
# Total params: 17,315
# Trainable params: 17,315
# Non-trainable params: 0
# _________________________________________________________________

# %%
LEARNING_RATE = 0.0005
BATCH_SIZE = 32
INITIAL_EPOCH = 0

AE.compile(LEARNING_RATE)

# %%
AE.train(     
    x_train, y_train
    , batch_size = BATCH_SIZE
    , epochs = 3000
    , run_folder = RUN_FOLDER
    , initial_epoch = INITIAL_EPOCH
)

AE.save(RUN_FOLDER)
# Out:
# Train on 3400 samples
# Epoch 1/3000
# 3296/3400 [============================>.] - ETA: 0s - loss: 0.1422 - mae: 0.3039
# Epoch 00001: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 2s 490us/sample - loss: 0.1395 - mae: 0.2984
# Epoch 2/3000
# 3232/3400 [===========================>..] - ETA: 0s - loss: 0.0256 - mae: 0.0722
# Epoch 00002: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 242us/sample - loss: 0.0249 - mae: 0.0709
# Epoch 3/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0081 - mae: 0.0389
# Epoch 00003: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 237us/sample - loss: 0.0080 - mae: 0.0387
# Epoch 4/3000
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.0054 - mae: 0.0332
# Epoch 00004: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s
saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 280us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2952/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02952: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 278us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2953/3000
# 3232/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02953: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 272us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2954/3000
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02954: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 287us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2955/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02955: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 297us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2956/3000
# 3200/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02956: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 277us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2957/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02957: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 272us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2958/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02958: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 271us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2959/3000
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02959: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 276us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2960/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0015 - mae: 0.0228
# Epoch 02960: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 274us/sample - loss: 0.0015 - mae: 0.0227
# Epoch 2961/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02961: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 276us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2962/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02962: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 284us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2963/3000
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02963: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 275us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2964/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02964: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 273us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2965/3000
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02965: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 278us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2966/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02966: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 279us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2967/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02967: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 283us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2968/3000
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0224
# Epoch 02968: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 283us/sample - loss: 0.0014 - mae: 0.0224
# Epoch 2969/3000
# 3232/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02969: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 299us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2970/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02970: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 274us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2971/3000
# 3200/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02971: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 274us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2972/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02972: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 281us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2973/3000
# 3232/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02973: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 271us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2974/3000
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02974: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 279us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2975/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02975: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 292us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2976/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02976: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 278us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2977/3000
# 3296/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02977: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 271us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2978/3000
# 3296/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02978: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 279us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2979/3000
# 3200/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02979: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 279us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2980/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02980: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 275us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2981/3000
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0227
# Epoch 02981: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 283us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2982/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02982: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 286us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2983/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02983: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 284us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2984/3000
# 3232/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02984: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 279us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2985/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02985: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 285us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2986/3000
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02986: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 284us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2987/3000
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02987: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 277us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2988/3000
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02988: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 288us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2989/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02989: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 284us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2990/3000
# 3296/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02990: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 271us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2991/3000
# 3232/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02991: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 275us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2992/3000
# 3232/3400 [===========================>..] - ETA: 0s - loss: 0.0015 - mae: 0.0226
# Epoch 02992: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 276us/sample - loss: 0.0015 - mae: 0.0226
# Epoch 2993/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02993: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 279us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2994/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02994: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 279us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2995/3000
# 3296/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0225
# Epoch 02995: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 284us/sample - loss: 0.0014 - mae: 0.0225
# Epoch 2996/3000
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02996: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 281us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2997/3000
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.0014 - mae: 0.0226- ETA: 0s - loss: 0.0014
# Epoch 02997: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 279us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 2998/3000
# 3232/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0227
# Epoch 02998: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 276us/sample - loss: 0.0014 - mae: 0.0227
# Epoch 2999/3000
# 3232/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 02999: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 272us/sample - loss: 0.0014 - mae: 0.0226
# Epoch 3000/3000
# 3264/3400 [===========================>..] - ETA: 0s - loss: 0.0014 - mae: 0.0226
# Epoch 03000: saving model to ../run/vae/0001_boson/weights/weights.h5
# 3400/3400 [==============================] - 1s 274us/sample - loss: 0.0014 - mae: 0.0226

# %%
def load_model(model_class, folder):
    
    with open(os.path.join(folder, 'params.pkl'), 'rb') as f:
        params = pickle.load(f)

    model = model_class(*params)
    model.load_weights(os.path.join(folder, 'weights/weights.h5'))

    return model

# %%
AE2 = load_model(Autoencoder, RUN_FOLDER)

# %%
n_to_show = 10
example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_test   = y_test[example_idx]

z_points = AE2.encoder.predict(example_images)
print('z_points: ', z_points)
reconst_images = AE.decoder.predict(z_points)
print('reconstituted: {}'.format(reconst_images))

# %%
print(z_points[0])

# %%
print(reconst_images[1])

# %%
print(sum(reconst_images[1]))

# %%
y_pos = np.arange(len(reconst_images[1]))

objects = list(range(len(reconst_images[1])))

plt.bar(y_pos, reconst_images[1], align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Probability')
plt.title('AE')

# %%
y_pos = np.arange(len(reconst_images[1]))

objects = list(range(len(reconst_images[1])))

plt.bar(y_pos, example_test[1], align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Probability')
plt.title('Actual')

# %%
y_test
